# %%
# %run LongTrail_BuildGraph.ipynb

# %%
from gurobipy import *

# Create a new model
m = Model()
# Out:
# Academic license - for non-commercial use only

# %%
#for each edge, create a variable in the model and add it to the objective function
#if the edge is required, create a separate constraint saying that the edge must be traversed at least once
gurobiVars = dict()
obj = LinExpr()

for u,v,a in G.edges(data=True):
    thisEdgeName = str(u) + "_" + str(v) if u < v else str(v) + "_" + str(u)
    thisVar = m.addVar(vtype=GRB.INTEGER, name=thisEdgeName)
    gurobiVars[thisEdgeName] = thisVar
    obj += (a['weight'] * (thisVar))
    if(a['required'] == 1):
        m.addConstr(thisVar >= 1)
    
m.setObjective(obj, GRB.MINIMIZE)

# %%
#now add constraints. A eulerian tour requires (and will always exist if) no more than two nodes are odd 
#(because the two odd nodes are the start and end node)
#But in this case, let's assume that all nodes are even (the "tour" starts and ends at the same node, "the road")

#note that Gurobi doesn't allow modulo operator, so to solve that, declare a dedicated int variable for each
#constraint, and then express each constraint in the form X + Y = 2z (for evenness)
for n in G.nodes():
    #TO DO: turn this into two constraints - one for "walking degree" and one for "driving degree". Both must be even.
    #the current implementation combines walking degree and driving degree, which doesn't make sense.
    WalkingConstraintForThisNode = LinExpr()
    DrivingConstraintForThisNode = LinExpr()
    thisNodeWalkingEvenOddVar = m.addVar(vtype=GRB.INTEGER, name="WalkingEvennessForNode" + str(n))
    thisNodeDrivingEvenOddVar = m.addVar(vtype=GRB.INTEGER, name="DrivingEvennessForNode" + str(n))
    for u,v,a in G.edges(n, data=True):
        edgeName = str(u) + "_" + str(v) if u < v else str(v) + "_" + str(u)
        thisEdge = gurobiVars[edgeName]
        if(u == 999 or v == 999):
            DrivingConstraintForThisNode += thisEdge
        else:
            WalkingConstraintForThisNode += thisEdge
    m.addConstr(WalkingConstraintForThisNode == (2*thisNodeWalkingEvenOddVar))  
    m.addConstr(DrivingConstraintForThisNode == (2*thisNodeDrivingEvenOddVar))

# %%
#do the thing
m.optimize()
# Out:
# Optimize a model with 611 rows, 735 columns and 1241 nonzeros
# Variable types: 0 continuous, 735 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e-01, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 458 rows and 392 columns
# Presolve time: 0.00s
# Presolved: 153 rows, 343 columns, 533 nonzeros
# Variable types: 0 continuous, 343 integer (0 binary)
#
# Root relaxation: objective 2.786000e+02, 84 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  278.60000    0   16          -  278.60000      -     -    0s
#      0     0  289.20000    0    8          -  289.20000      -     -    0s
#      0     0  291.30000    0    6          -  291.30000      -     -    0s
#      0     0  291.90000    0    4          -  291.90000      -     -    0s
#      0     0  291.90000    0    6          -  291.90000      -     -    0s
#      0     0  292.50000    0    2          -  292.50000      -     -    0s
# H    0     0                     293.6000000  292.50000  0.37%     -    0s
#      0     0  292.60000    0    2  293.60000  292.60000  0.34%     -    0s
#      0     0  292.60000    0    6  293.60000  292.60000  0.34%     -    0s
#      0     0  292.60000    0    2  293.60000  292.60000  0.34%     -    0s
# H    0     0                     292.8000000  292.60000  0.07%     -    0s
#      0     0  292.70000    0    2  292.80000  292.70000  0.03%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   MIR: 12
#   Zero half: 6
#
# Explored 1 nodes (173 simplex iterations) in 0.06 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 292.8 293.6 293.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.928000000000e+02, best bound 2.928000000000e+02, gap 0.0000%

# %%
#print the results, sorted by variable name
vList = m.getVars()
vList.sort(key=lambda var: int(var.varName[:var.varName.find("_",0)]) if var.varName.find("_",0) > 0 else 1000 )


for v in vList:
    print('%s %g' % (v.varName, v.x))

print('Obj: %g' % m.objVal)
# Out:
# 0_2 0
# 1_2 2
# 1_999 2
# 2_3 0
# 3_4 0
# 3_999 2
# 4_5 0
# 5_6 0
# 6_10 0
# 6_999 2
# 7_9 1
# 7_8 1
# 7_999 2
# 8_9 1
# 8_999 2
# 9_12 2
# 10_12 0
# 10_11 2
# 11_999 2
# 12_13 0
# 13_15 0
# 14_23 1
# 14_16 1
# 14_999 2
# 15_17 0
# 15_999 2
# 16_21 1
# 16_999 2
# 17_18 0
# 18_19 2
# 18_20 0
# 19_24 2
# 20_21 0
# 21_22 1
# 22_23 1
# 22_25 0
# 23_25 2
# 23_27 2
# 24_999 2
# 25_26 0
# 26_29 0
# 27_999 2
# 28_999 2
# 29_30 0
# 29_999 2
# 30_32 0
# 30_999 2
# 31_32 2
# 31_999 2
# 32_38 1
# 32_33 1
# 33_35 1
# 33_36 0
# 34_35 2
# 34_999 2
# 35_36 1
# 36_37 1
# 37_39 1
# 38_39 1
# 38_999 2
# 39_41 0
# 40_44 2
# 40_41 2
# 41_42 0
# 41_999 2
# 42_43 0
# 43_46 0
# 44_45 2
# 45_999 2
# 46_49 2
# 46_47 2
# 49_51 2
# 49_53 0
# 50_999 2
# 51_999 2
# 53_54 0
# 53_999 2
# 54_55 0
# 54_999 2
# 55_56 0
# 56_57 0
# 57_58 0
# 58_60 0
# 59_61 1
# 59_63 1
# 59_999 2
# 60_62 0
# 61_63 1
# 61_999 2
# 62_64 0
# 63_64 2
# 64_66 0
# 65_66 2
# 66_67 2
# 67_68 2
# 67_69 0
# 68_999 2
# 69_70 1
# 69_74 1
# 70_71 2
# 70_72 1
# 72_76 1
# 72_74 -0
# 72_999 2
# 73_75 2
# 74_77 1
# 74_999 2
# 75_78 1
# 75_76 1
# 77_78 1
# 77_80 0
# 79_80 2
# 79_999 2
# 80_84 0
# 81_84 2
# 81_83 2
# 82_999 2
# 83_86 2
# 84_85 0
# 85_87 0
# 85_999 2
# 86_999 2
# 87_88 2
# 87_90 0
# 88_999 2
# 89_91 2
# 90_91 2
# 90_999 2
# 91_93 0
# 92_93 2
# 92_95 -0
# 92_999 2
# 93_94 -0
# 94_97 0
# 94_95 2
# 95_999 2
# 96_98 2
# 96_999 2
# 97_98 1
# 97_99 1
# 98_100 1
# 99_100 1
# 99_999 2
# 100_101 0
# 101_103 0
# 101_999 2
# 102_103 2
# 102_999 2
# 103_105 0
# 104_105 2
# 104_999 2
# DrivingEvennessForNode8 1
# WalkingEvennessForNode12 1
# DrivingEvennessForNode12 -0
# WalkingEvennessForNode10 1
# DrivingEvennessForNode10 -0
# WalkingEvennessForNode11 1
# DrivingEvennessForNode11 1
# WalkingEvennessForNode14 1
# DrivingEvennessForNode14 1
# WalkingEvennessForNode23 3
# DrivingEvennessForNode23 -0
# WalkingEvennessForNode25 1
# DrivingEvennessForNode25 -0
# WalkingEvennessForNode22 1
# DrivingEvennessForNode22 -0
# WalkingEvennessForNode27 1
# DrivingEvennessForNode27 1
# WalkingEvennessForNode16 1
# DrivingEvennessForNode16 1
# WalkingEvennessForNode21 1
# DrivingEvennessForNode21 -0
# WalkingEvennessForNode19 2
# DrivingEvennessForNode19 -0
# WalkingEvennessForNode24 1
# DrivingEvennessForNode24 1
# WalkingEvennessForNode18 1
# DrivingEvennessForNode18 -0
# WalkingEvennessForNode35 2
# DrivingEvennessForNode35 -0
# WalkingEvennessForNode36 1
# DrivingEvennessForNode36 -0
# WalkingEvennessForNode40 2
# DrivingEvennessForNode40 -0
# WalkingEvennessForNode44 2
# DrivingEvennessForNode44 -0
# WalkingEvennessForNode41 1
# DrivingEvennessForNode41 1
# WalkingEvennessForNode31 1
# DrivingEvennessForNode31 1
# WalkingEvennessForNode32 2
# DrivingEvennessForNode32 -0
# WalkingEvennessForNode45 1
# DrivingEvennessForNode45 1
# WalkingEvennessForNode49 2
# DrivingEvennessForNode49 -0
# WalkingEvennessForNode51 1
# DrivingEvennessForNode51 1
# WalkingEvennessForNode34 1
# DrivingEvennessForNode34 1
# WalkingEvennessForNode33 1
# DrivingEvennessForNode33 -0
# WalkingEvennessForNode42 0
# DrivingEvennessForNode42 -0
# WalkingEvennessForNode43 0
# DrivingEvennessForNode43 -0
# WalkingEvennessForNode38 1
# DrivingEvennessForNode38 1
# WalkingEvennessForNode39 1
# DrivingEvennessForNode39 -0
# WalkingEvennessForNode46 2
# DrivingEvennessForNode46 -0
# WalkingEvennessForNode47 1
# DrivingEvennessForNode47 -0
# WalkingEvennessForNode61 1
# DrivingEvennessForNode61 1
# WalkingEvennessForNode63 2
# DrivingEvennessForNode63 -0
# WalkingEvennessForNode67 2
# DrivingEvennessForNode67 -0
# WalkingEvennessForNode68 1
# DrivingEvennessForNode68 1
# WalkingEvennessForNode65 1
# DrivingEvennessForNode65 -0
# WalkingEvennessForNode66 2
# DrivingEvennessForNode66 -0
# WalkingEvennessForNode70 2
# DrivingEvennessForNode70 -0
# WalkingEvennessForNode71 1
# DrivingEvennessForNode71 -0
# WalkingEvennessForNode69 1
# DrivingEvennessForNode69 -0
# WalkingEvennessForNode72 1
# DrivingEvennessForNode72 1
# WalkingEvennessForNode59 1
# DrivingEvennessForNode59 1
# WalkingEvennessForNode64 1
# DrivingEvennessForNode64 -0
# WalkingEvennessForNode81 2
# DrivingEvennessForNode81 -0
# WalkingEvennessForNode84 1
# DrivingEvennessForNode84 -0
# WalkingEvennessForNode83 2
# DrivingEvennessForNode83 -0
# WalkingEvennessForNode86 1
# DrivingEvennessForNode86 1
# WalkingEvennessForNode77 1
# DrivingEvennessForNode77 -0
# WalkingEvennessForNode78 1
# DrivingEvennessForNode78 -0
# WalkingEvennessForNode75 2
# DrivingEvennessForNode75 -0
# WalkingEvennessForNode76 1
# DrivingEvennessForNode76 -0
# WalkingEvennessForNode73 1
# DrivingEvennessForNode73 -0
# WalkingEvennessForNode79 1
# DrivingEvennessForNode79 1
# WalkingEvennessForNode80 1
# DrivingEvennessForNode80 -0
# WalkingEvennessForNode92 1
# DrivingEvennessForNode92 1
# WalkingEvennessForNode93 1
# DrivingEvennessForNode93 -0
# WalkingEvennessForNode96 1
# DrivingEvennessForNode96 1
# WalkingEvennessForNode98 2
# DrivingEvennessForNode98 -0
# WalkingEvennessForNode99 1
# DrivingEvennessForNode99 1
# WalkingEvennessForNode100 1
# DrivingEvennessForNode100 -0
# WalkingEvennessForNode97 1
# DrivingEvennessForNode97 -0
# WalkingEvennessForNode89 1
# DrivingEvennessForNode89 -0
# WalkingEvennessForNode91 2
# DrivingEvennessForNode91 -0
# WalkingEvennessForNode94 1
# DrivingEvennessForNode94 -0
# WalkingEvennessForNode95 1
# DrivingEvennessForNode95 1
# WalkingEvennessForNode87 1
# DrivingEvennessForNode87 -0
# WalkingEvennessForNode88 1
# DrivingEvennessForNode88 1
# WalkingEvennessForNode102 1
# DrivingEvennessForNode102 1
# WalkingEvennessForNode103 1
# DrivingEvennessForNode103 -0
# WalkingEvennessForNode111 1
# DrivingEvennessForNode111 -0
# WalkingEvennessForNode112 1
# DrivingEvennessForNode112 1
# WalkingEvennessForNode104 1
# DrivingEvennessForNode104 1
# WalkingEvennessForNode105 1
# DrivingEvennessForNode105 -0
# WalkingEvennessForNode106 1
# DrivingEvennessForNode106 -0
# WalkingEvennessForNode107 2
# DrivingEvennessForNode107 -0
# WalkingEvennessForNode109 1
# DrivingEvennessForNode109 1
# WalkingEvennessForNode108 1
# DrivingEvennessForNode108 -0
# WalkingEvennessForNode116 1
# DrivingEvennessForNode116 -0
# WalkingEvennessForNode119 1
# DrivingEvennessForNode119 -0
# WalkingEvennessForNode123 2
# DrivingEvennessForNode123 -0
# WalkingEvennessForNode125 1
# DrivingEvennessForNode125 -0
# WalkingEvennessForNode127 1
# DrivingEvennessForNode127 -0
# WalkingEvennessForNode118 2
# DrivingEvennessForNode118 -0
# WalkingEvennessForNode120 1
# DrivingEvennessForNode120 1
# WalkingEvennessForNode126 2
# DrivingEvennessForNode126 -0
# WalkingEvennessForNode131 1
# DrivingEvennessForNode131 1
# WalkingEvennessForNode132 2
# DrivingEvennessForNode132 -0
# WalkingEvennessForNode133 1
# DrivingEvennessForNode133 -0
# WalkingEvennessForNode121 2
# DrivingEvennessForNode121 -0
# WalkingEvennessForNode117 1
# DrivingEvennessForNode117 -0
# WalkingEvennessForNode115 1
# DrivingEvennessForNode115 1
# WalkingEvennessForNode122 1
# DrivingEvennessForNode122 1
# WalkingEvennessForNode113 1
# DrivingEvennessForNode113 1
# WalkingEvennessForNode114 1
# DrivingEvennessForNode114 -0
# WalkingEvennessForNode178 1
# DrivingEvennessForNode178 -0
# WalkingEvennessForNode179 1
# DrivingEvennessForNode179 -0
# WalkingEvennessForNode156 1
# DrivingEvennessForNode156 -0
# WalkingEvennessForNode162 1
# DrivingEvennessForNode162 -0
# WalkingEvennessForNode186 2
# DrivingEvennessForNode186 -0
# WalkingEvennessForNode189 1
# DrivingEvennessForNode189 1
# WalkingEvennessForNode187 2
# DrivingEvennessForNode187 -0
# WalkingEvennessForNode140 1
# DrivingEvennessForNode140 1
# WalkingEvennessForNode143 2
# DrivingEvennessForNode143 -0
# WalkingEvennessForNode170 2
# DrivingEvennessForNode170 -0
# WalkingEvennessForNode173 1
# DrivingEvennessForNode173 -0
# WalkingEvennessForNode165 2
# DrivingEvennessForNode165 -0
# WalkingEvennessForNode171 2
# DrivingEvennessForNode171 -0
# WalkingEvennessForNode169 2
# DrivingEvennessForNode169 -0
# WalkingEvennessForNode158 2
# DrivingEvennessForNode158 -0
# WalkingEvennessForNode166 1
# DrivingEvennessForNode166 -0
# WalkingEvennessForNode154 1
# DrivingEvennessForNode154 1
# WalkingEvennessForNode188 1
# DrivingEvennessForNode188 -0
# WalkingEvennessForNode136 1
# DrivingEvennessForNode136 -0
# WalkingEvennessForNode137 -0
# DrivingEvennessForNode137 -0
# WalkingEvennessForNode182 1
# DrivingEvennessForNode182 -0
# WalkingEvennessForNode185 1
# DrivingEvennessForNode185 -0
# WalkingEvennessForNode142 1
# DrivingEvennessForNode142 -0
# WalkingEvennessForNode150 2
# DrivingEvennessForNode150 -0
# WalkingEvennessForNode151 1
# DrivingEvennessForNode151 -0
# WalkingEvennessForNode145 2
# DrivingEvennessForNode145 -0
# WalkingEvennessForNode159 1
# DrivingEvennessForNode159 -0
# WalkingEvennessForNode152 2
# DrivingEvennessForNode152 -0
# WalkingEvennessForNode160 1
# DrivingEvennessForNode160 1
# WalkingEvennessForNode177 1
# DrivingEvennessForNode177 -0
# WalkingEvennessForNode180 2
# DrivingEvennessForNode180 -0
# WalkingEvennessForNode181 1
# DrivingEvennessForNode181 1
# WalkingEvennessForNode135 1
# DrivingEvennessForNode135 1
# WalkingEvennessForNode153 -0
# DrivingEvennessForNode153 -0
# WalkingEvennessForNode163 1
# DrivingEvennessForNode163 -0
# WalkingEvennessForNode176 2
# DrivingEvennessForNode176 -0
# WalkingEvennessForNode148 1
# DrivingEvennessForNode148 -0
# WalkingEvennessForNode146 2
# DrivingEvennessForNode146 -0
# WalkingEvennessForNode147 2
# DrivingEvennessForNode147 -0
# WalkingEvennessForNode149 1
# DrivingEvennessForNode149 -0
# WalkingEvennessForNode138 1
# DrivingEvennessForNode138 -0
# WalkingEvennessForNode139 1
# DrivingEvennessForNode139 1
# WalkingEvennessForNode144 2
# DrivingEvennessForNode144 -0
# WalkingEvennessForNode183 1
# DrivingEvennessForNode183 1
# WalkingEvennessForNode184 2
# DrivingEvennessForNode184 -0
# WalkingEvennessForNode172 1
# DrivingEvennessForNode172 -0
# WalkingEvennessForNode141 1
# DrivingEvennessForNode141 -0
# WalkingEvennessForNode190 1
# DrivingEvennessForNode190 -0
# WalkingEvennessForNode191 1
# DrivingEvennessForNode191 -0
# WalkingEvennessForNode161 0
# DrivingEvennessForNode161 -0
# WalkingEvennessForNode198 1
# DrivingEvennessForNode198 -0
# WalkingEvennessForNode199 2
# DrivingEvennessForNode199 1
# WalkingEvennessForNode200 1
# DrivingEvennessForNode200 1
# WalkingEvennessForNode195 1
# DrivingEvennessForNode195 1
# WalkingEvennessForNode196 1
# DrivingEvennessForNode196 -0
# WalkingEvennessForNode203 1
# DrivingEvennessForNode203 1
# WalkingEvennessForNode204 2
# DrivingEvennessForNode204 -0
# WalkingEvennessForNode205 1
# DrivingEvennessForNode205 -0
# WalkingEvennessForNode201 1
# DrivingEvennessForNode201 -0
# WalkingEvennessForNode210 1
# DrivingEvennessForNode210 1
# WalkingEvennessForNode211 1
# DrivingEvennessForNode211 -0
# WalkingEvennessForNode0 -0
# DrivingEvennessForNode0 -0
# WalkingEvennessForNode3 -0
# DrivingEvennessForNode3 1
# WalkingEvennessForNode4 -0
# DrivingEvennessForNode4 -0
# WalkingEvennessForNode5 -0
# DrivingEvennessForNode5 -0
# WalkingEvennessForNode6 -0
# DrivingEvennessForNode6 1
# WalkingEvennessForNode13 0
# DrivingEvennessForNode13 -0
# WalkingEvennessForNode15 0
# DrivingEvennessForNode15 1
# WalkingEvennessForNode17 0
# DrivingEvennessForNode17 -0
# WalkingEvennessForNode20 0
# DrivingEvennessForNode20 -0
# WalkingEvennessForNode26 0
# DrivingEvennessForNode26 -0
# WalkingEvennessForNode29 0
# DrivingEvennessForNode29 1
# WalkingEvennessForNode30 0
# DrivingEvennessForNode30 1
# WalkingEvennessForNode37 1
# DrivingEvennessForNode37 -0
# WalkingEvennessForNode53 0
# DrivingEvennessForNode53 1
# WalkingEvennessForNode54 0
# DrivingEvennessForNode54 1
# WalkingEvennessForNode55 0
# DrivingEvennessForNode55 -0
# WalkingEvennessForNode56 0
# DrivingEvennessForNode56 -0
# WalkingEvennessForNode57 -0
# DrivingEvennessForNode57 -0
# WalkingEvennessForNode58 0
# DrivingEvennessForNode58 -0
# WalkingEvennessForNode60 0
# DrivingEvennessForNode60 -0
# WalkingEvennessForNode62 0
# DrivingEvennessForNode62 -0
# WalkingEvennessForNode74 1
# DrivingEvennessForNode74 1
# WalkingEvennessForNode85 0
# DrivingEvennessForNode85 1
# WalkingEvennessForNode90 1
# DrivingEvennessForNode90 1
# WalkingEvennessForNode101 0
# DrivingEvennessForNode101 1
# WalkingEvennessForNode110 0
# DrivingEvennessForNode110 1
# WalkingEvennessForNode128 0
# DrivingEvennessForNode128 1
# WalkingEvennessForNode129 0
# DrivingEvennessForNode129 1
# WalkingEvennessForNode130 0
# DrivingEvennessForNode130 1
# WalkingEvennessForNode157 1
# DrivingEvennessForNode157 -0
# WalkingEvennessForNode167 0
# DrivingEvennessForNode167 -0
# WalkingEvennessForNode168 -0
# DrivingEvennessForNode168 -0
# WalkingEvennessForNode164 0
# DrivingEvennessForNode164 -0
# WalkingEvennessForNode175 0
# DrivingEvennessForNode175 -0
# WalkingEvennessForNode192 0
# DrivingEvennessForNode192 -0
# WalkingEvennessForNode193 0
# DrivingEvennessForNode193 1
# WalkingEvennessForNode194 0
# DrivingEvennessForNode194 1
# WalkingEvennessForNode197 0
# DrivingEvennessForNode197 1
# WalkingEvennessForNode206 -0
# DrivingEvennessForNode206 1
# WalkingEvennessForNode207 -0
# DrivingEvennessForNode207 1
# WalkingEvennessForNode208 -0
# DrivingEvennessForNode208 -0
# WalkingEvennessForNode209 -0
# DrivingEvennessForNode209 1
# WalkingEvennessForNode174 0
# DrivingEvennessForNode174 1
# WalkingEvennessForNode999 -0
# DrivingEvennessForNode999 75
# WalkingEvennessForNode28 -0
# DrivingEvennessForNode28 1
# WalkingEvennessForNode50 -0
# DrivingEvennessForNode50 1
# WalkingEvennessForNode82 -0
# DrivingEvennessForNode82 1
# WalkingEvennessForNode124 -0
# DrivingEvennessForNode124 1
# WalkingEvennessForNode134 -0
# DrivingEvennessForNode134 1
# WalkingEvennessForNode155 -0
# DrivingEvennessForNode155 1
# Obj: 292.8

# %%
#so the answer is that if you do it all in one trip, the total cost of trails that you need to double-back on
#is 135.1. That's in addition to walking each path once, so add the 437.5 = 572.6 total miles

# %%
#subtour elimination (NOT needed at this point)
#  Find the total set of nodes included in the subtour, and then the edges adjacent to all of those nodes. 
#  The total value of those edges must be less than what it is right now

# %%
#convert results to graph and do a DFS to make sure it's all connected
FinalGraph=nx.Graph()

for v in vList:
    if(v.varName.find("Evenness") == -1):
        if(v.x > 0):
            edgeNodes = v.varName.split('_')
            FinalGraph.add_edge(edgeNodes[0],edgeNodes[1])

sub_graphs = nx.connected_component_subgraphs(FinalGraph)
#sub_graphs.sort(key=lambda var:var.number_of_nodes())

for i, sg in enumerate(sub_graphs):
    print("subgraph" , str(i), " has ", str(sg.number_of_nodes()))
    print ("\tNodes:", sg.nodes(data=True))
    print ("\tEdges:", sg.edges())
# Out:
# subgraph 0  has  186
