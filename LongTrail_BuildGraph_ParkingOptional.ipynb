# %%
#before this script, I identified all of the necessary nodes 
#and numbered them starting at the southern terminus of the Long Trail (node 0)
#and ending at the northern terminus (node 211)
#this script will turn those nodes into a graph

import networkx as nx
import matplotlib.pyplot as plt

G=nx.Graph()
nodes={}

# %%
#First, create the nodes
nodeCount = 0
nodeFile = open("C:/Users/cmj7g/Dropbox/VT/Long_Trail/nodes.txt","r") 
thisNode = nodeFile.readline().strip()
while thisNode:
    thisNode = eval(thisNode)
    thisNodeAsList = list(thisNode)
    thisNodeAsList[1] = 29298-thisNodeAsList[1]
    thisNode = tuple(thisNodeAsList)
    nodes[nodeCount] = thisNode
    thisNode = nodeFile.readline().strip()
    nodeCount += 1

nx.set_node_attributes(G, 'coord', nodes)

# %%
#now add all the trails

#####
#DIVISION 1
#####
#Broad Brook Trail	4.0
G.add_edge(1,2, weight=4.0, required=1)

#####
#DIVISION 2
#####
#Bald Mountain Trail	5.9
G.add_edge(7,9, weight=4.0, required=1)
G.add_edge(8,9, weight=1.9, required=1)
#West Ridge Trail	7.8
G.add_edge(9,12, weight=7.8, required=1)
#Little Pond Access Trail	0.5
G.add_edge(10,11, weight=0.5, required=1)

#####
#DIVISION 3
#####
#Branch Pond Trail	8.3
G.add_edge(14,23, weight=4.3, required=1)
G.add_edge(23,25, weight=4.0, required=1)
#Lye Brook Trail	9.7
G.add_edge(22,23, weight=2.4, required=1)
G.add_edge(23,27, weight=7.3, required=1)
#Stratton Pond Trail	3.7
G.add_edge(16,21, weight=3.7, required=1)
#Wanderer Trail	2.4
G.add_edge(19,24, weight=2.4, required=1)
#Stratton Ridge Trail	0.7
G.add_edge(18,19, weight=0.7, required=1)

#####
#DIVISION 4
#####
#Baker Peak Trail	0.9
G.add_edge(35,36, weight=0.9, required=1)
#Green Mountain Trail	4.1
G.add_edge(40,44, weight=4.1, required=1)
#Green Mountain Trail Connector 	0.6
G.add_edge(40,41, weight=0.6, required=1)
#Griffith Lake Trail	2.0
G.add_edge(31,32, weight=2.0, required=1)
#Homer Stone Brook Trail	2.3
G.add_edge(44,45, weight=2.3, required=1)
#Keewaydin Trail	0.4
G.add_edge(49,51, weight=0.4, required=1)
#Lake Trail	3.3
G.add_edge(34,35, weight=1.9, required=1)
G.add_edge(35,33, weight=1.4, required=1)
#Little Rock Pond Loop	0.4
G.add_edge(42,43, weight=0.4, required=1)
#Old Job Trail	5.4
G.add_edge(32,38, weight=3.4, required=1)
G.add_edge(38,39, weight=2.0, required=1)
#White Rocks Cliff Trail	0.2
G.add_edge(46,47, weight=0.2, required=1)

#####
#DIVISION 5
#####
#Black Swamp Trail	2.2
G.add_edge(61,63, weight=2.2, required=1)
#Bucklin Trail	3.5
G.add_edge(67,68, weight=3.5, required=1)
#Killington Peak Spur	0.2
G.add_edge(65,66, weight=0.2, required=1)
#Pico Link Trail	0.4
G.add_edge(70,71, weight=0.4, required=1)
#Sherburne Pass Trail (south)	3.1
G.add_edge(69,70, weight=0.4, required=1)
G.add_edge(70,72, weight=2.7, required=1)
#Shrewsbury Peak Trail	4.0
G.add_edge(59,63, weight=1.9, required=1)
G.add_edge(63,64, weight=2.1, required=1)

#####
#DIVISION 6
#####
#Chittenden Brook Trail	3.7
G.add_edge(81,84, weight=1.7, required=1)
G.add_edge(81,83, weight=0.1, required=1)
G.add_edge(83,86, weight=1.9, required=1)
#Deer Leap Trail	1.3
G.add_edge(77,78, weight=0.1, required=0) #this segment isn't included in the mileage, but it's necessary to connect to the trail)
G.add_edge(75,78, weight=0.9, required=1)
G.add_edge(75,76, weight=0.4, required=1)
#Deer Leap Overlook Spur	0.2
G.add_edge(73,75, weight=0.2, required=1)
#New Boston Trail	1.2
G.add_edge(79,80, weight=1.2, required=1)
#Sherburne Pass Trail (north)	0.5
G.add_edge(72,76, weight=0.5, required=1)

#####
#DIVISION 7
#####
#Burnt Hill Trail	2.2
G.add_edge(92,93, weight=2.2, required=1)
#Clark Brook Trail	3.0
G.add_edge(96,98, weight=3.0, required=1)
#Cooley Glen Trail	3.2
G.add_edge(99,100, weight=3.2, required=1)
#Emily Proctor Trail	3.5
G.add_edge(97,99, weight=3.5, required=1)
#Silent Cliff Trail	0.4
G.add_edge(89,91, weight=0.4, required=1)
#Skylight Pond Trail	2.6
G.add_edge(94,95, weight=2.6, required=1)
#Sucker Brook Trail	1.0
G.add_edge(87,88, weight=1.0, required=1)

#####
#DIVISION 8
#####
#Battell Trail	2.0
G.add_edge(102,103, weight=2.0, required=1)
#Beane Trail	1.5
G.add_edge(111,112, weight=1.5, required=1)
#Jerusalem Trail	2.4
G.add_edge(104,105, weight=2.4, required=1)
#Stark Mountain Trail	2.4
G.add_edge(106,107, weight=0.8, required=1)
G.add_edge(107,109, weight=1.6, required=1)
#Sunnyside Trail	0.4
G.add_edge(107,108, weight=0.4, required=1)

#####
#DIVISION 9
#####
#Allis Trail	0.3
G.add_edge(116,119, weight=0.3, required=1)
#Alpine Trail	1.7
G.add_edge(123,125, weight=0.5, required=1)
G.add_edge(123,127, weight=1.2, required=1)
#Burrows-Forest City Connector	0.1
G.add_edge(118,120, weight=0.1, required=1)
#Burrows Trail	2.1
G.add_edge(120,126, weight=2.1, required=1)
#Duck Brook Trail	5.4
G.add_edge(131,132, weight=4.5, required=1)
G.add_edge(132,133, weight=0.9, required=1)
#Dean Trail	1.0
G.add_edge(119,121, weight=1.0, required=1)
#Forest City Trail	2.2
G.add_edge(117,118, weight=1.4, required=1)
G.add_edge(118,115, weight=0.8, required=1)
#Monroe Trail	3.1
G.add_edge(123,126, weight=0.6, required=1)
G.add_edge(123,121, weight=1.2, required=1)
G.add_edge(121,122, weight=1.3, required=1)
#Hedgehog Brook Trail	2.0
G.add_edge(113,114, weight=2.0, required=1)

#####
#DIVISION 10
#####
#Adam's Apple Trail	0.2
G.add_edge(178,179, weight=0.2, required=1)
#Amherst Trail	0.3
G.add_edge(156,162, weight=0.3, required=1)
#Beaver Meadow Trail	2.3
G.add_edge(186,189, weight=2.2, required=1)
G.add_edge(186,187, weight=0.1, required=1)
#Butler Lodge Trail	1.8
G.add_edge(140,143, weight=1.8, required=1)
#Cantilever Rock Trail	0.2
G.add_edge(170,173, weight=0.2, required=1)
#Canyon North Extension	0.6
G.add_edge(165,171, weight=0.6, required=1)
G.add_edge(169,171, weight=0.1, required=1)
#Canyon North Trail	0.6
G.add_edge(158,165, weight=0.6, required=1)
G.add_edge(165,166, weight=0.1, required=1)
#Canyon Trail	0.6
G.add_edge(154,158, weight=0.6, required=1)
#Chilcoot Trail	0.8
G.add_edge(187,188, weight=0.8, required=1)
#Clara Bow Trail	0.4
G.add_edge(136,137, weight=0.4, required=1)
#Cliff Trail	1.1
G.add_edge(156,169, weight=1.1, required=1)
#Elephant's Head Trail	0.7
G.add_edge(182,185, weight=0.7, required=1)
#Forehead Bypass	1.2
G.add_edge(142,150, weight=0.9, required=1)
G.add_edge(150,151, weight=0.3, required=1)
#Frost Trail	1.4
G.add_edge(140,145, weight=1.4, required=1)
#Halfway House Trail	0.9
G.add_edge(158,159, weight=0.9, required=1)
#Haselton Trail	1.6
G.add_edge(152,160, weight=1.6, required=1)
#Hell Brook Cutoff	0.7
G.add_edge(177,180, weight=0.7, required=1)
#Hell Brook Trail	1.5
G.add_edge(178,179, weight=0.2, required=1)
G.add_edge(179,180, weight=0.4, required=1)
G.add_edge(180,181, weight=0.9, required=1)
#Lake Mansfield Trail	1.6
G.add_edge(135,136, weight=1.6, required=1)
#Lakeview Trail	0.8
G.add_edge(153,154, weight=0.8, required=1)
#Laura Cowles Trail	1.4
G.add_edge(163,176, weight=1.4, required=1)
#Maple Ridge Trail	1.3
G.add_edge(145,148, weight=0.4, required=1)
G.add_edge(145,146, weight=0.4, required=1)
G.add_edge(146,147, weight=0.5, required=1)
G.add_edge(147,149, weight=0.2, required=0)#this segment isn't included in the mileage, but it's necessary to connect to the trail)
#Nebraska Notch Trail	1.5
G.add_edge(138,139, weight=1.5, required=1)
#Profanity Trail	0.5
G.add_edge(176,177, weight=0.5, required=1)
#Rock Garden Trail	3.6
G.add_edge(146,144, weight=3.6, required=1)
#Sterling Pond Trail	1.1
G.add_edge(183,184, weight=1.1, required=1)
#Sunset Ridge Trail	2.0
G.add_edge(163,170, weight=0.6, required=1)
G.add_edge(170,176, weight=1.4, required=1)
#South Link	0.6
G.add_edge(150,152, weight=0.6, required=1)
#Subway Trail	0.3
G.add_edge(171,172, weight=0.3, required=1)
#Wallace Cutoff	0.1
G.add_edge(141,143, weight=0.1, required=1)
#Wampahoofus Trail	0.6
G.add_edge(143,144, weight=0.1, required=1)
G.add_edge(144,147, weight=0.5, required=1)
#Whiteface Trail	1.0
G.add_edge(190,191, weight=0.9, required=1)
G.add_edge(187,190, weight=0.1, required=1)
#A bunch of little connectors around
#beaver meadow lodge aren't included, but they're important
#to link up.
G.add_edge(186,190, weight=0.1, required=0)
#Linkups between the halfway house trail and laura cowles trail
G.add_edge(159,161, weight=0.2, required=0)
G.add_edge(161,163, weight=0.1, required=0)


#####
#DIVISION 11
#####
#Babcock Trail	1.4
G.add_edge(198,199, weight=1.4, required=1)
#Babcock Trail Extension	0.4
G.add_edge(199,200, weight=0.4, required=1)
#Davis Neighborhood Trail	1.5
G.add_edge(195,196, weight=1.5, required=1)
#Frank Post Trail	2.0
G.add_edge(203,204, weight=0.6, required=1)
G.add_edge(204,205, weight=1.4, required=1)
#Forester's Trail	2.1
G.add_edge(201,204, weight=2.1, required=1)

#####
#DIVISION 12
#####
#Journey's End Trail	1.3
G.add_edge(210,211, weight=1.3, required=1)

# %%
#####
#THE LONG TRAIL
#is optional, but it's available if needed to connect trails
#
#there are a few segments that I want to include for now
#so I've marked them as required
#####
G.add_edge(0,2, weight=2.6, required=0)
G.add_edge(2,3, weight=0.5, required=0)
G.add_edge(3,4, weight=4.9, required=0)
G.add_edge(4,5, weight=2.6, required=0)
G.add_edge(5,6, weight=3.7, required=0)
G.add_edge(6,10, weight=4.8, required=0)
G.add_edge(10,12, weight=5.3, required=0)
G.add_edge(12,13, weight=10.2, required=0 )
G.add_edge(13,15, weight=2.0, required=0)    
G.add_edge(15,17, weight=1.4, required=0)    
G.add_edge(17,18, weight=2.4, required=0)    
G.add_edge(18,20, weight=2.1, required=0)    
G.add_edge(20,21, weight=1.0, required=0)    
G.add_edge(21,22, weight=0.1, required=0)    
G.add_edge(22,25, weight= 4.7, required=0)    
G.add_edge(25,26, weight=0.9 , required=0 )    
G.add_edge(26,29, weight=4.9 , required=0 )    
G.add_edge(29,30, weight=5.5 , required=0 )    
G.add_edge(30,32, weight=5.3 , required=0 )    
G.add_edge(32,33, weight=0.1 , required=0 )    
G.add_edge(33,36, weight=1.8 , required=0 )    
G.add_edge(36,37, weight=0.2 , required=0 )    
G.add_edge(37,39, weight=3.5 , required=0 )    
G.add_edge(39,41, weight=1.5 , required=0 )    
G.add_edge(41,42, weight=2.0 , required=0 )    
G.add_edge(42,43, weight=0.3 , required=0 )    
G.add_edge(43,46, weight=4.0 , required=0)    
G.add_edge(46,49, weight=1.0 , required=1 )
G.add_edge(49,53, weight=0.8 , required=0 )           
G.add_edge(53,54, weight=6.3 , required=0 )           
G.add_edge(54,55, weight=1.9 , required=0 )           
G.add_edge(55,56, weight=2.0 , required=0 )           
G.add_edge(56,57, weight=0.1 , required=0 )           
G.add_edge(57,58, weight=1.5 , required=0 )           
G.add_edge(58,60, weight= 0.7 , required=0)           
G.add_edge(60,62, weight=0.7  , required=0)           
G.add_edge(62,64, weight=2.7  , required=0)           
G.add_edge(64,66, weight=1.5  , required=0)           
G.add_edge(66,67, weight= 0.1 , required=1)           
G.add_edge(67,69, weight=2.3  , required=0)           
G.add_edge(69,74, weight=3.8  , required=0)           
G.add_edge(74,77, weight=1.0  , required=0)           
G.add_edge(77,80, weight=11  , required=0)           
G.add_edge(80,84, weight= 4.9 , required=0)           
G.add_edge(84,85, weight=2.3  , required=0)           
G.add_edge(85,87, weight= 5.2 , required=0)           
G.add_edge(87,90, weight=4.5  , required=0)           
G.add_edge(90,91, weight=0.4  , required=1)           
G.add_edge(91,93, weight= 2.1 , required=0)           
G.add_edge(93,94, weight=2.6  , required=0)           
G.add_edge(94,97, weight= 1.8 , required=0)           
G.add_edge(97,98, weight= 1.7 , required=0)           
G.add_edge(98,100, weight=4.0 , required=0)           
G.add_edge(100,101, weight=4.7, required=0 )           
G.add_edge(101,103, weight=1.7, required=0 )           
G.add_edge(103,105, weight=6.4, required=0 )           
G.add_edge(105,106, weight=1.0, required=0 )           
G.add_edge(106,108, weight=1.0, required=0 )           
G.add_edge(108,110, weight=1.5, required=0 )           
G.add_edge(110,111, weight=2.6, required=0 )           
G.add_edge(111,114, weight=3.8, required=0 )           
G.add_edge(114,116, weight=4.0, required=0 )           
G.add_edge(116,117, weight=0.2, required=0 )           
G.add_edge(117,119, weight=0.2, required=0 )           
G.add_edge(119,125, weight=1.5, required=0 )           
G.add_edge(125,126, weight=0.5, required=0 )           
G.add_edge(126,127, weight=0.8, required=0 )           
G.add_edge(127,128, weight=5.2, required=0)  
G.add_edge(128,129, weight=0.8, required=0 )           
G.add_edge(129,130, weight=2.0, required=0 )           
G.add_edge(130,133, weight=4.9, required=0 )           
G.add_edge(133,136, weight=9  , required=0 )           
G.add_edge(136,137, weight=0.4, required=0 )           
G.add_edge(137,138, weight=0.3, required=0 )           
G.add_edge(138,141, weight=2.6, required=0 )           
G.add_edge(141,142, weight=0.2, required=0 )           
G.add_edge(142,149, weight=0.7, required=0 )           
G.add_edge(149,151, weight= 0.6, required=0)           
G.add_edge(151,153, weight=0.1, required=0 )           
G.add_edge(153,154, weight=0.1, required=0 )           
G.add_edge(154,157, weight=0.2, required=0 )           
G.add_edge(157,162, weight=0.3, required=0 )           
G.add_edge(162,166, weight=0.2, required=0 )           
G.add_edge(166,169, weight=0.3, required=0 )           
G.add_edge(169,172, weight=0.1, required=0 )           
G.add_edge(172,176, weight=0.2, required=0 )           
G.add_edge(176,178, weight=0.5, required=0 )           
G.add_edge(178,177, weight=0.3, required=0 )           
G.add_edge(177,167, weight=1.7, required=0 )           
G.add_edge(167,168, weight=0.1, required=0 )           
G.add_edge(168,164, weight=0.4, required=0 )           
G.add_edge(164,175, weight=0.5, required=0 )           
G.add_edge(175,182, weight=3.1, required=0 )           
G.add_edge(182,184, weight=0.3, required=0 )           
G.add_edge(184,185, weight=0.3, required=0 )           
G.add_edge(185,188, weight=2.0, required=0 )
G.add_edge(188,191, weight=1.5, required=0 )
G.add_edge(191,192, weight=6.9, required=0 )           
G.add_edge(192,193, weight=0.6, required=0 )           
G.add_edge(193,194, weight=4.2, required=0 )           
G.add_edge(194,197, weight=2.4, required=0 )           
G.add_edge(197,196, weight=4.9, required=0 )           
G.add_edge(196,198, weight=7.6, required=0 )           
G.add_edge(198,200, weight=2.0, required=0 )           
G.add_edge(200,201, weight=2.6, required=0 )           
G.add_edge(201,205, weight=2.8, required=0 )           
G.add_edge(205,206, weight=4.6, required=0 )           
G.add_edge(206,207, weight=6.8, required=0 )           
G.add_edge(207,208, weight= 0.3, required=0)           
G.add_edge(208,209, weight= 9.0, required=0)           
G.add_edge(209,211, weight=2.6, required=0 )

# %%
#There are a few places wheree it might make sense to walk on the road
G.add_edge(14,16, weight=0.8, required=0 )  #i guessed the distance here 
G.add_edge(7,8, weight=5.1, required=0 )  #i guessed the distance here 
G.add_edge(59,61, weight=1.3, required=0 )
G.add_edge(72,74, weight=1.2, required=0 )  #i guessed the distance here 
G.add_edge(92,95, weight=2.5, required=0 )
G.add_edge(115,120, weight=0.7, required=0 )
G.add_edge(130,131, weight=1.3, required=0 )
G.add_edge(139,140, weight=0.2, required=0 )
G.add_edge(167,174, weight=0.4, required=0 )
G.add_edge(174,181, weight=1.0, required=0 )
G.add_edge(181,183, weight=1.0, required=0 )

# %%
#Now add parking. For now, I'm going to assume that driving is free.
#So to simulate that, I'm going to create a single node (#999) that represents "the road" 
#for every node that has parking, I'll create an optional 0-weight edge to node 999,
#which functionally means that you can get from that node to any other parking node for free

nodesWithParkingFile = open("C:/Users/cmj7g/Dropbox/VT/Long_Trail/nodes_that_have_parking.txt","r") 
thisParkingLot = nodesWithParkingFile.readline().strip()
while thisParkingLot:
    G.add_edge(int(thisParkingLot),999, weight=0, required=0 )   
    thisParkingLot = nodesWithParkingFile.readline().strip()

# %%
#Show the graph
#plt.figure(1,figsize=(100,100))
#nx.draw(G,pos=nodes,with_labels=True, node_size=60,font_size=8)
#plt.show()
